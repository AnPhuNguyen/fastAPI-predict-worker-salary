# %% [markdown]
# this was done with base from https://www.geeksforgeeks.org/ml-multiple-linear-regression-using-python/

# %%
import pandas as pd

# %%
# Load dataset
df = pd.read_csv('salaries_2.csv')
df
# Out:
#     years_of_experience  skills_met  union_status  salary
# 0                     5           3             0    3150
# 1                     9           5             1    3787
# 2                     4           2             0    2991
# 3                    10           6             1    4551
# 4                     8           4             1    3540
# ..                  ...         ...           ...     ...
# 95                    4           2             0    2884
# 96                    4           2             0    2810
# 97                    2           1             0    2488
# 98                    7           5             1    3661
# 99                    2           1             0    2496
#
# [100 rows x 4 columns]

# %%
x = pd.DataFrame(df.iloc[:,0:3])
x
# df.columns[0:3]
# Out:
#     years_of_experience  skills_met  union_status
# 0                     5           3             0
# 1                     9           5             1
# 2                     4           2             0
# 3                    10           6             1
# 4                     8           4             1
# ..                  ...         ...           ...
# 95                    4           2             0
# 96                    4           2             0
# 97                    2           1             0
# 98                    7           5             1
# 99                    2           1             0
#
# [100 rows x 3 columns]

# %%
y = pd.Series(df.iloc[:,3])
y
# Out:
# 0     3150
# 1     3787
# 2     2991
# 3     4551
# 4     3540
#       ...
# 95    2884
# 96    2810
# 97    2488
# 98    3661
# 99    2496
# Name: salary, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
model = LinearRegression()

model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# x_test

y_pred = model.predict(x_test)
y_pred
# Out:
# array([2893.46709822, 3443.92607686, 2515.64560886, 3443.92607686,
#        4103.92234648, 2566.94160888, 2849.11638915, 3219.99258756,
#        3726.10085712, 3443.92607686, 3443.92607686, 3777.39685714,
#        2515.64560886, 3392.63007684, 3117.40058752, 3667.85956616,
#        3828.69285716, 3502.16736782, 2566.94160888, 3443.92607686])

# %%
y_pred-y_test
# Out:
# 96     83.467098
# 43     34.926077
# 82    -50.354391
# 23    154.926077
# 3    -447.077654
# 93   -105.058391
# 9    -128.883611
# 69    165.992588
# 39    165.100857
# 83    -39.073923
# 58     11.926077
# 31   -128.603143
# 12    278.645609
# 21    -24.369923
# 70     33.400588
# 71     79.859566
# 85   -306.307143
# 15     35.167368
# 77    -77.058391
# 59    108.926077
# Name: salary, dtype: float64

# %%
input_data = pd.DataFrame([[5, 3, 0]], columns=x.columns) 
# if pass in predict() with plain array, cause a warinng:
# UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
predict_result = model.predict(input_data)
predict_result[0]
# Out:
# 3168.6965875376345

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
r2*100
# Out:
# 90.83234469275952

# %%
import pickle
with open('module_pickle.pkl','wb') as f:
    pickle.dump(model,f)
    
# this part was done with https://www.youtube.com/watch?v=KfnhNlD8WZI
